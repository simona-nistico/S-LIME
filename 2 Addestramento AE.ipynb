# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/Tesi\ Magistrale\ 204963/Progetto/

import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Tesi Magistrale 204963/Progetto

# %% [markdown]
# YAHOO
# ===

# %%
# !python autoencoders/train.py --train data/yahoo/train_2_pre.txt --valid data/yahoo/test_2_pre.txt --model_type aae --lambda_adv 10 --noise 0.3,0,0,0 --batch-size 512 --vocab-size 25000 --save-dir mytest/checkpoint/yahoo/daae_1
# Out:
# Namespace(batch_size=512, dim_d=512, dim_emb=512, dim_h=1024, dim_z=128, dropout=0.5, epochs=50, lambda_adv=10.0, lambda_kl=0, lambda_p=0, load_model='', log_interval=100, lr=0.0005, model_type='aae', nlayers=1, no_cuda=False, noise=[0.3, 0.0, 0.0, 0.0], save_dir='mytest/checkpoint/yahoo/daae_1', seed=1111, train='data/yahoo/train_2_pre.txt', valid='data/yahoo/test_2_pre.txt', vocab_size=25000)
# # train sents 280000, tokens 3649575
# # valid sents 12000, tokens 157084
# # vocab size 12005
# # model parameters: 38007782
# --------------------------------------------------------------------------------
# | epoch   1 |   100/  579 batches | rec 100.71, adv 0.78, |lvar| 52.50, loss_d 1.30, loss 108.55,
# | epoch   1 |   200/  579 batches | rec 94.68, adv 0.69, |lvar| 67.76, loss_d 1.43, loss 101.56,
# | epoch   1 |   300/  579 batches | rec 79.48, adv 0.84, |lvar| 64.86, loss_d 1.37, loss 87.93,
# ...

# %%
# !python autoencoders/train.py --load-model mytest/checkpoint/yahoo/daae_1/model.pt --train data/yahoo/train_2_pre.txt --valid data/yahoo/test_2_pre.txt --model_type aae --lambda_adv 10 --noise 0.3,0,0,0 --batch-size 512 --vocab-size 25000 --save-dir mytest/checkpoint/yahoo/daae_1
# Out:
# Namespace(batch_size=512, dim_d=512, dim_emb=512, dim_h=1024, dim_z=128, dropout=0.5, epochs=50, lambda_adv=10.0, lambda_kl=0, lambda_p=0, load_model='mytest/checkpoint/yahoo/daae_1/model.pt', log_interval=100, lr=0.0005, model_type='aae', nlayers=1, no_cuda=False, noise=[0.3, 0.0, 0.0, 0.0], save_dir='mytest/checkpoint/yahoo/daae_1', seed=1111, train='data/yahoo/train_2_pre.txt', valid='data/yahoo/test_2_pre.txt', vocab_size=25000)
# # train sents 280000, tokens 3649575
# # valid sents 12000, tokens 157084
# # vocab size 12005
# # model parameters: 38007782
# --------------------------------------------------------------------------------
# | epoch   1 |   100/  579 batches | rec 33.81, adv 0.68, |lvar| 1077.73, loss_d 1.42, loss 40.65,
# | epoch   1 |   200/  579 batches | rec 36.51, adv 0.70, |lvar| 1082.63, loss_d 1.43, loss 43.47,
# | epoch   1 |   300/  579 batches | rec 30.74, adv 0.69, |lvar| 1067.00, loss_d 1.41, loss 37.63,
# ...

# %%
# !python autoencoders/test.py --sample --n 100 --checkpoint mytest/checkpoint/yahoo/daae_1/ --output sample.txt

# %%
with open("mytest/checkpoint/yahoo/daae_1/sample.txt",'r') as f:
  data = f.readlines()
  f.close()

data
# Out:
# ['how to find the internet <unk> in yahoo messenger ?\n',
#  'how on my cd - r . a . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_ . _num_\n',
#  'do you hate the truth ?\n',
#  'what is the best book / desktop / mac ?\n',
#  'what is the <unk> ? i want to see my yahoo mail ?\n',
#  'is it true that the <unk> of the world is a new <unk> ?\n',
#  'what is a good item on ebay for a good place to do on ebay . com ?\n',
#  'how do i find a proxy server for an internet ?\n',
#  'what is the best way to use <unk> of " <unk> "?\n',
#  "we can ' t believe in the world , is there a higher than _num_ . _num_ . _num_ . _num_ ?\n",
#  'why do people <unk> in <unk> with the same <unk> world ?\n',
#  'can a <unk> , and i have a _num_ year old son of death ?\n',
#  'if you were to be married , and god ?\n',
#  'how to <unk> the <unk> of a <unk> to be ? what is the future ?\n',
#  'how can i make sure that i have scanned my picture file ?\n',
# ...

# %%
# !python autoencoders/test.py --reconstruct --data data/yahoo/test_2_pre.txt --output test_2.rec --checkpoint mytest/checkpoint/yahoo/daae_1/

# %% [markdown]
# YELP
# ===

# %%
# !python autoencoders/train.py --train data/yelp/train.txt --valid data/yelp/valid.txt --model_type aae --lambda_adv 10 --noise 0.3,0,0,0 --batch-size 512 --vocab-size 12000 --save-dir mytest/checkpoint/yelp/daae_1
# Out:
# Namespace(batch_size=512, dim_d=512, dim_emb=512, dim_h=1024, dim_z=128, dropout=0.5, epochs=50, lambda_adv=10.0, lambda_kl=0, lambda_p=0, load_model='', log_interval=100, lr=0.0005, model_type='aae', nlayers=1, no_cuda=False, noise=[0.3, 0.0, 0.0, 0.0], save_dir='mytest/checkpoint/yelp/daae_1', seed=1111, train='data/yelp/train.txt', valid='data/yelp/valid.txt', vocab_size=12000)
# # train sents 200000, tokens 1821469
# # valid sents 10000, tokens 90833
# # vocab size 12005
# # model parameters: 38007782
# --------------------------------------------------------------------------------
# | epoch   1 |   100/  397 batches | rec 65.05, adv 0.82, |lvar| 57.49, loss_d 1.31, loss 73.26,
# | epoch   1 |   200/  397 batches | rec 56.48, adv 0.80, |lvar| 55.69, loss_d 1.36, loss 64.48,
# | epoch   1 |   300/  397 batches | rec 60.15, adv 0.65, |lvar| 62.12, loss_d 1.45, loss 66.65,
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# TWITTER
# ===

# %%
# !python autoencoders/train.py --train data/twitter/twitter_train.txt --valid data/twitter/twitter_test.txt --model_type aae --lambda_adv 10 --noise 0.3,0,0,0 --batch-size 512 --vocab-size 12000 --save-dir mytest/checkpoint/twitter/daae_1
# Out:
# Namespace(batch_size=512, dim_d=512, dim_emb=512, dim_h=1024, dim_z=128, dropout=0.5, epochs=50, lambda_adv=10.0, lambda_kl=0, lambda_p=0, load_model='', log_interval=100, lr=0.0005, model_type='aae', nlayers=1, no_cuda=False, noise=[0.3, 0.0, 0.0, 0.0], save_dir='mytest/checkpoint/twitter/daae_1', seed=1111, train='data/twitter/twitter_train.txt', valid='data/twitter/twitter_test.txt', vocab_size=12000)
# # train sents 300000, tokens 4002575
# # valid sents 1000, tokens 13534
# # vocab size 12005
# # model parameters: 38007782
# --------------------------------------------------------------------------------
# | epoch   1 |   100/  616 batches | rec 100.42, adv 0.85, |lvar| 102.74, loss_d 1.27, loss 108.94,
# | epoch   1 |   200/  616 batches | rec 89.41, adv 0.69, |lvar| 120.25, loss_d 1.41, loss 96.28,
# | epoch   1 |   300/  616 batches | rec 88.27, adv 0.70, |lvar| 95.40, loss_d 1.47, loss 95.30,
# ...
